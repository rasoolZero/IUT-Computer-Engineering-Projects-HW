# %%
import pandas

# %%
#Question 5_1
Data = pandas.read_csv('Smartphone.csv')

# %%
Data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
#Question 5_2
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
#Question 5_3
Data[(Data['blue'] == 1) & (Data['int_memory'] > 10)]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 4              1821     1          1.2         0  13       1          44
# 8              1445     1          0.5         0   0       0          53
# 11             1520     1          2.2         0   5       1          33
# ...             ...   ...          ...       ...  ..     ...         ...
# 1990           1617     1          2.4         0   8       1          36
# 1992            674     1          2.9         1   1       0          21
# 1993           1467     1          0.5         0   0       0          18
# 1996           1965     1          2.6         1   0       0          39
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#Question 5_4
Data[Data['fc'] == Data['fc'].max()]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1705           1290     1          1.4         1  19       1          35
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width  ram  sc_h  sc_w  \
# 1705    0.3        110        4  ...        405       742  879    16     2
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1705          8        1             0     0            0
#
# [1 rows x 21 columns]

# %%
Data[Data['fc'] == Data['fc'].min()]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1              1021     1          0.5         1   0       1          53
# 3               615     1          2.5         0   0       0          10
# 7              1954     0          0.5         1   0       0          24
# 8              1445     1          0.5         0   0       0          53
# 10              769     1          2.9         1   0       0           9
# ...             ...   ...          ...       ...  ..     ...         ...
# 1971            538     0          1.1         1   0       1          25
# 1984            797     0          2.2         1   0       0          37
# 1993           1467     1          0.5         0   0       0          18
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#Question 5_5
Data.loc[Data['clock_speed'] <= 1,'clock_rate'] = 'Low'
Data.loc[(Data['clock_speed'] > 1) & (Data['clock_speed'] <= 2),'clock_rate'] = 'Mid'
Data.loc[Data['clock_speed'] > 2,'clock_rate'] = 'High'

# %%
Data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0        188        2  ...       756  2549     9     7         19        0
# 1        136        3  ...      1988  2631    17     3          7        1
# 2        145        5  ...      1716  2603    11     2          9        1
# 3        131        6  ...      1786  2769    16     8         11        1
# 4        141        2  ...      1212  1411     8     2         15        1
#
#    touch_screen  wifi  price_range  clock_rate
# ...

# %%
#Question 5_6
import seaborn
import matplotlib.pyplot as plt

plt.subplots(figsize = (15, 15))

seaborn.heatmap(Data.corr(), annot = True, fmt = '.1g',cmap = 'YlGn')
# Out:
# <AxesSubplot:>

# %%
#Question 5_7
Data['battery_power'].hist(figsize = (15, 5))
# Out:
# <AxesSubplot:>

# %%
#Question 6_1
Data = pandas.read_csv('Student.csv')

# %%
Data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#Question 6_2
Data.loc[Data['gender'] == 'female']['math score'].hist()
Data.loc[Data['gender'] == 'male']['math score'].hist()
# Out:
# <AxesSubplot:>

# %%
print('female mean:', Data.loc[Data['gender'] == 'female']['math score'].mean())
print('male mean:', Data.loc[Data['gender'] == 'male']['math score'].mean())

print('female min:', Data.loc[Data['gender'] == 'female']['math score'].min())
print('male min:', Data.loc[Data['gender'] == 'male']['math score'].min())

print('female max:', Data.loc[Data['gender'] == 'female']['math score'].max())
print('male max:', Data.loc[Data['gender'] == 'male']['math score'].max())
# Out:
# female mean: 63.633204633204635
# male mean: 68.72821576763485
# female min: 0
# male min: 27
# female max: 100
# male max: 100

# %%
#Question 6_3
Data1 = pandas.DataFrame(Data['race/ethnicity'].value_counts(), 
                        index = list(Data['race/ethnicity'].unique()), columns = ['race/ethnicity'])
plot = Data1.plot.pie(y = 'race/ethnicity', figsize = (15, 15), cmap = 'tab20')

# %%
#Question 6_4
Data['total_grade'] = (Data['math score'] + Data['reading score'] + Data['writing score']) / 3

# %%
Data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_grade
# 0    72.666667
# 1    82.333333
# 2    92.666667
# 3    49.333333
# 4    76.333333

# %%
#Question 6_5
pandas.crosstab(Data['parental level of education'], Data['gender'])
# Out:
# gender                       female  male
# parental level of education
# associate's degree              116   106
# bachelor's degree                63    55
# high school                      94   102
# master's degree                  36    23
# some college                    118   108
# some high school                 91    88

# %%
#Question 7_1
Data = pandas.read_csv("Housing.csv")

# %%
Data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
#Question 7_2
Data = Data.dropna()

# %%
#Question 7_3
Data['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
#Question 7_4
Data.plot(kind = "scatter", x = "longitude", y = "latitude", s = Data['population']/100, label = "population",
        c = "median_house_value", cmap = "jet", colorbar = True, alpha = 0.4, figsize = (10,7))

plt.legend(); plt.show()
