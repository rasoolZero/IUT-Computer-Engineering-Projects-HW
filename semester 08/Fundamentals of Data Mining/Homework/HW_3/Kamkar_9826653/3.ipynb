# %% [markdown]
# #### generating random 2-spiral data

# %%
import numpy as np
from numpy import pi

N = 400
theta = np.sqrt(np.random.rand(N))*2*pi # np.linspace(0,2*pi,100)

r_a = 2*theta + pi
data_a = np.array([np.cos(theta)*r_a, np.sin(theta)*r_a]).T
x_a = data_a + np.random.randn(N,2)

r_b = -2*theta - pi
data_b = np.array([np.cos(theta)*r_b, np.sin(theta)*r_b]).T
x_b = data_b + np.random.randn(N,2)

res_a = np.append(x_a, np.zeros((N,1)), axis=1)
res_b = np.append(x_b, np.ones((N,1)), axis=1)

res = np.append(res_a, res_b, axis=0)
np.random.shuffle(res)

# %%
from matplotlib import pyplot as plt
plt.scatter(res[:,0],res[:,1],c=res[:,2],cmap = 'viridis',s=20)

# %%
from sklearn.cluster import KMeans
for i in range(10):
    model = KMeans(n_clusters=2,init='random',n_init='auto')
    labels = model.fit_predict(res[:,0:1])
    plt.figure()
    plot = plt.scatter(res[:,0],res[:,1],c=labels,cmap = 'viridis',s=20)
    plt.show()
